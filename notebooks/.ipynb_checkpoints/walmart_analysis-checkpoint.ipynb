# %%
# importing the necessary libraries
import pandas as pd
import numpy as np
import functions as f
import matplotlib.pyplot as plt
import seaborn as sns
import yaml

# %%
try:
    with open("../config.yaml", "r") as file:
        config = yaml.safe_load(file)
except:
    print("Configuration yaml file not found!")

# %%
config['data']['raw']
# Out:
# '../data/raw/WMT_Grocery_202209.csv'

# %%
# load the walmart dataset 
walmart_df = pd.read_csv(config['data']['raw'], low_memory=False)
#walmart_df = pd.read_csv(r"../data/raw/WMT_Grocery_202209.csv",low_memory=False)
walmart_df
# Out:
#          index  SHIPPING_LOCATION DEPARTMENT               CATEGORY  \
# 0            0              79936       Deli  Hummus, Dips, & Salsa
# 1            1              79936       Deli  Hummus, Dips, & Salsa
# 2            2              79936       Deli  Hummus, Dips, & Salsa
# 3            3              79936       Deli  Hummus, Dips, & Salsa
# 4            4              79936       Deli  Hummus, Dips, & Salsa
# ...        ...                ...        ...                    ...
# 568529  568529              70072    Alcohol                   Wine
# 568530  568530              70072    Alcohol                   Wine
# 568531  568531              70072    Alcohol                   Wine
# 568532  568532              70072    Alcohol                   Wine
# 568533  568533              70072    Alcohol                   Wine
#
#        SUBCATEGORY                 BREADCRUMBS        SKU  \
# 0              NaN  Deli/Hummus, Dips, & Salsa  110895339
# 1              NaN  Deli/Hummus, Dips, & Salsa  105455228
# 2              NaN  Deli/Hummus, Dips, & Salsa  128642379
# 3              NaN  Deli/Hummus, Dips, & Salsa  366126367
# 4              NaN  Deli/Hummus, Dips, & Salsa  160090316
# ...            ...                         ...        ...
# 568529  White Wine                Alcohol/Wine  593600139
# 568530  White Wine                Alcohol/Wine  333403243
# 568531  White Wine                Alcohol/Wine  526588325
# 568532  White Wine                Alcohol/Wine  286992782
# 568533  White Wine                Alcohol/Wine  160015930
#
#                                               PRODUCT_URL  \
# 0       https://www.walmart.com/ip/Marketside-Roasted-...
# 1       https://www.walmart.com/ip/Marketside-Roasted-...
# 2       https://www.walmart.com/ip/Marketside-Classic-...
# 3       https://www.walmart.com/ip/Marketside-Everythi...
# 4       https://www.walmart.com/ip/Price-s-Jalapeno-Di...
# ...                                                   ...
# 568529  https://www.walmart.com/ip/Farm-Fresh-Blueberr...
# 568530  https://www.walmart.com/ip/Farm-Fresh-Peach-Mo...
# 568531  https://www.walmart.com/ip/Farm-Fresh-Raspberr...
# 568532  https://www.walmart.com/ip/Farm-Fresh-Mango-Mo...
# 568533  https://www.walmart.com/ip/Ole-Orleans-Heritag...
#
#                                        PRODUCT_NAME                    BRAND  \
# 0       Marketside Roasted Red Pepper Hummus, 10 Oz               Marketside
# 1           Marketside Roasted Garlic Hummus, 10 Oz               Marketside
# 2                  Marketside Classic Hummus, 10 Oz               Marketside
# 3               Marketside Everything Hummus, 10 oz               Marketside
# 4                      Price's Jalapeno Dip, 12 Oz.                  Price's
# ...                                             ...                      ...
# 568529           Farm Fresh Blueberry Moscato 750ml  Farm Fresh Wine Company
# 568530              Farm Fresh Peach Moscato 750 Ml  Farm Fresh Wine Company
# 568531           Farm Fresh Raspberry Moscato 750ml  Farm Fresh Wine Company
# 568532               Farm Fresh Mango Moscato 750ml  Farm Fresh Wine Company
# 568533          Ole Orleans Heritage Riesling 750ml              Ole Orleans
#
#         PRICE_RETAIL  PRICE_CURRENT PRODUCT_SIZE  PROMOTION  \
# 0               2.67           2.67           10        NaN
# 1               2.67           2.67           10        NaN
# 2               2.67           2.67           10        NaN
# 3               2.67           2.67           10        NaN
# 4               3.12           3.12           12        NaN
# ...              ...            ...          ...        ...
# 568529          9.98           9.98          750        NaN
# 568530          9.98           9.98          750        NaN
# 568531          9.98           9.98          750        NaN
# 568532          9.98           9.98          750        NaN
# 568533         18.98          18.98          750        NaN
#
#                     RunDate       tid
# 0       2022-09-11 21:20:04  16163804
# 1       2022-09-11 21:20:04  16163805
# 2       2022-09-11 21:20:04  16163806
# 3       2022-09-11 21:20:04  16163807
# 4       2022-09-11 21:20:04  16163808
# ...                     ...       ...
# 568529  2022-09-11 21:20:04  16732333
# 568530  2022-09-11 21:20:04  16732334
# 568531  2022-09-11 21:20:04  16732335
# 568532  2022-09-11 21:20:04  16732336
# 568533  2022-09-11 21:20:04  16732337
#
# [568534 rows x 16 columns]

# %%
f.print_in_red("Informations about DataFrame")
walmart_df.info()
# Out:
# Informations about DataFrame
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568534 entries, 0 to 568533
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   index              568534 non-null  int64
#  1   SHIPPING_LOCATION  568534 non-null  int64
#  2   DEPARTMENT         568534 non-null  object
#  3   CATEGORY           568534 non-null  object
#  4   SUBCATEGORY        361324 non-null  object
#  5   BREADCRUMBS        568534 non-null  object
#  6   SKU                568534 non-null  int64
#  7   PRODUCT_URL        568534 non-null  object
#  8   PRODUCT_NAME       568534 non-null  object
#  9   BRAND              568507 non-null  object
#  10  PRICE_RETAIL       568534 non-null  float64
#  11  PRICE_CURRENT      568534 non-null  float64
#  12  PRODUCT_SIZE       505709 non-null  object
#  13  PROMOTION          0 non-null       float64
#  14  RunDate            568534 non-null  object
#  15  tid                568534 non-null  int64
# dtypes: float64(3), int64(4), object(9)
# memory usage: 69.4+ MB

# %%
(walmart_df['PRICE_RETAIL'] == walmart_df['PRICE_CURRENT']).all()
# Out:
# False

# %%
walmart_df[ walmart_df['PRICE_RETAIL'] != walmart_df['PRICE_CURRENT'] ]
# Out:
#          index  SHIPPING_LOCATION DEPARTMENT       CATEGORY SUBCATEGORY  \
# 110        110              48180  Beverages  Energy Drinks         NaN
# 121        121              48180  Beverages  Energy Drinks         NaN
# 129        129              48180  Beverages  Energy Drinks         NaN
# 154        154              48180  Beverages  Energy Drinks         NaN
# 158        158              48180  Beverages  Energy Drinks         NaN
# ...        ...                ...        ...            ...         ...
# 568016  568016              75052    Alcohol           Wine  White Wine
# 568042  568042              85225    Alcohol           Wine  White Wine
# 568157  568157              85225    Alcohol           Wine  White Wine
# 568272  568272              30044    Alcohol           Wine  White Wine
# 568356  568356              75211    Alcohol           Wine  White Wine
#
#                     BREADCRUMBS        SKU  \
# 110     Beverages/Energy Drinks   46535268
# 121     Beverages/Energy Drinks  291822869
# 129     Beverages/Energy Drinks  291822869
# 154     Beverages/Energy Drinks  109000435
# 158     Beverages/Energy Drinks   14944717
# ...                         ...        ...
# 568016             Alcohol/Wine  123406562
# 568042             Alcohol/Wine   10984620
# 568157             Alcohol/Wine  645437337
# 568272             Alcohol/Wine  162244320
# 568356             Alcohol/Wine  118409182
#
#                                               PRODUCT_URL  \
# 110     https://www.walmart.com/ip/Rockstar-Punched-Fr...
# 121     https://www.walmart.com/ip/C4-Energy-Drink-Str...
# 129     https://www.walmart.com/ip/C4-Energy-Drink-Str...
# 154     https://www.walmart.com/ip/C4-Energy-Drink-Fro...
# 158     https://www.walmart.com/ip/Rockstar-Original-E...
# ...                                                   ...
# 568016  https://www.walmart.com/ip/Ferrari-Carano-Char...
# 568042  https://www.walmart.com/ip/Kendall-Jackson-Vin...
# 568157  https://www.walmart.com/ip/Astoria-Pinot-Grigi...
# 568272  https://www.walmart.com/ip/La-Marca-Prosecco-S...
# 568356  https://www.walmart.com/ip/Chloe-Pinot-Grigio-...
#
#                                              PRODUCT_NAME  \
# 110     Rockstar Punched Fruit Punch Energy Drink, 16 ...
# 121     C4 Energy Drink + Strawberry Watermelon Ice + ...
# 129     C4 Energy Drink + Strawberry Watermelon Ice + ...
# 154     C4 Energy Drink + Frozen Bombsicle + Zero Suga...
# 158     Rockstar Original Energy Drink, 16 oz, 4 Pack ...
# ...                                                   ...
# 568016                   Ferrari Carano Chardonnay, 750mL
# 568042  Kendall-Jackson Vintner's Reserve Chardonnay W...
# 568157                  Astoria Pinot Grigio Wine, 750 mL
# 568272       La Marca Prosecco Sparkling White Wine 187ml
# 568356              Chloe Pinot Grigio White Wine - 750ml
#
#                         BRAND  PRICE_RETAIL  PRICE_CURRENT PRODUCT_SIZE  \
# 110                  Rockstar          5.28           4.75           16
# 121                        C4          2.28           1.98           16
# 129                        C4          2.28           1.98           16
# 154                        C4          2.28           1.98           16
# 158                  Rockstar          5.28           4.75           16
# ...                       ...           ...            ...          ...
# 568016         Ferrari-Carano         20.98          18.48          750
# 568042        Kendall-Jackson         12.98          11.48          750
# 568157                Astoria          9.98           8.48          750
# 568272               LA MARCA          6.73           5.98          187
# 568356  Chloe Wine Collection         13.98          12.48          750
#
#         PROMOTION              RunDate       tid
# 110           NaN  2022-09-11 21:20:04  16163914
# 121           NaN  2022-09-11 21:20:04  16163925
# 129           NaN  2022-09-11 21:20:04  16163933
# 154           NaN  2022-09-11 21:20:04  16163958
# 158           NaN  2022-09-11 21:20:04  16163962
# ...           ...                  ...       ...
# 568016        NaN  2022-09-11 21:20:04  16731820
# 568042        NaN  2022-09-11 21:20:04  16731846
# 568157        NaN  2022-09-11 21:20:04  16731961
# 568272        NaN  2022-09-11 21:20:04  16732076
# 568356        NaN  2022-09-11 21:20:04  16732160
#
# [11795 rows x 16 columns]

# %%
f.print_in_red("Shape of DataFrame")
print(f"rows: {walmart_df.shape[0]}\ncolumns: {walmart_df.shape[1]}")
# Out:
# Shape of DataFrame
# rows: 568534
# columns: 16

# %%
# Cleaning the columns name
f.clean_column_names(walmart_df)

# %%
# dropping unwanted columns
f.drop_columns(walmart_df,["index","tid","promotion"])

# %%
# checking null values
walmart_df.isnull().sum()
# Out:
# shipping_location         0
# department                0
# category                  0
# subcategory          207210
# breadcrumbs               0
# sku                       0
# product_url               0
# product_name              0
# brand                    27
# price_retail              0
# price_current             0
# product_size          62825
# rundate                   0
# dtype: int64

# %%
walmart_df.columns
# Out:
# Index(['shipping_location', 'department', 'category', 'subcategory',
#        'breadcrumbs', 'sku', 'product_url', 'product_name', 'brand',
#        'price_retail', 'price_current', 'product_size', 'rundate'],
#       dtype='object')

# %%
# Filling null values
walmart_df["subcategory"] = f.fillna_col(walmart_df,"subcategory","Not_Available")
walmart_df["brand"] = f.fillna_col(walmart_df, "brand", "Unknown")

# %%
# Convert 'product_size' to numeric, coercing errors to NaN
walmart_df['product_size'] = pd.to_numeric(walmart_df['product_size'], errors='coerce')
# Convert NaN to 0 (or handle them as needed)
walmart_df['product_size'] = walmart_df['product_size'].fillna(0)
# Convert to integers datatype
walmart_df['product_size'] = walmart_df['product_size'].astype(int)

# %%
# Converting to datetime datatype
walmart_df["rundate"] = pd.to_datetime(walmart_df["rundate"],format="%Y-%m-%d  %H:%M:%S", errors='coerce')
walmart_df["rundate"] = walmart_df["rundate"].dt.strftime("%d/%m/%Y %H:%M:%S")

# %% [markdown]
# **Grouping**

# %%
f.print_in_red('Unique subcategory count by department')
walmart_df.groupby(["department"])[["subcategory"]].nunique()
# Out:
# Unique subcategory count by department
#                     subcategory
# department
# Alcohol                      17
# Bakery & Bread               41
# Baking                        1
# Beverages                    16
# Breakfast & Cereal           23
# Candy                         1
# Coffee                        7
# Dairy & Eggs                  1
# Deli                          1
# Fresh Produce                 1
# Frozen                        1
# Meat & Seafood               23
# Pantry                        4
# Snacks                        1

# %%
# Group by brand and calculate the average current price
brand_avg_price = walmart_df.groupby('brand')['price_current'].mean().reset_index()
f.print_in_red("Top 5 Brands by Average Price")
display(brand_avg_price.sort_values(by = 'price_current', ascending=False, ignore_index=True).head())
# Out:
# Top 5 Brands by Average Price
#                             brand  price_current
# 0                       Nespresso     155.000000
# 1                           Ninja     153.000000
# 2  READY AMERICA-TREVCO-QUAKEHOLD      84.825000
# 3                Caymus Vineyards      82.230000
# 4                         Gourmia      81.078621

# %%
# Group by category and calculate the total sales (sum of current prices)
category_sales = walmart_df.groupby('category')['price_current'].sum().reset_index()
f.print_in_red("Top 5 Categories by Total Sales")
display(category_sales.sort_values(by='price_current', ascending=False, ignore_index=True).head())
# Out:
# Top 5 Categories by Total Sales
#                 category  price_current
# 0             Fresh Food      238935.54
# 1    Breakfast Beverages      185318.75
# 2         Coffee By Type      104070.15
# 3             Condiments       93984.46
# 4  Frozen Meals & Snacks       88789.12

# %%
# Create discount column and a discount data frame for further analysis
walmart_df['discount'] = walmart_df['price_retail'] - walmart_df['price_current']
discount_df = walmart_df[walmart_df['discount'] > 0 ]

# %%
disocunt_by_category = discount_df.groupby('category')['discount'].mean().reset_index()
f.print_in_red("Top 5 Categories highest average discount")
display(disocunt_by_category.sort_values(by = 'discount', ascending=False, ignore_index=True).head())
# Out:
# Top 5 Categories highest average discount
#                          category   discount
# 0                   Pasta & pizza  45.896471
# 1  Emergency & Institutional food  22.340000
# 2          Hard candy & lollipops   8.610000
# 3                        Pretzels   8.310000
# 4                     Drink Mixes   7.346119

# %%
# Count the number of products per brand in each department
f.print_in_red('Top 5 Brands and Departments with total items sold')
brand_department_count = walmart_df.groupby(['brand', 'department']).size().reset_index(name='counts').sort_values(by='counts', ascending=False, ignore_index=True)
display(brand_department_count.head())
# Out:
# Top 5 Brands and Departments with total items sold
#                   brand          department  counts
# 0           Great Value              Pantry   18147
# 1           Great Value           Beverages   13767
# 2           Great Value  Breakfast & Cereal   11959
# 3  Freshness Guaranteed      Bakery & Bread    8664
# 4           Great Value              Frozen    7860

# %%
f.print_in_red('Group by subcategory and brand to get unique product sizes sold')
product_sizes = walmart_df.groupby(['brand','subcategory'])['product_size'].unique().reset_index()
# Count the number of unique product sizes for each subcategory and brand
product_sizes['size_count'] =product_sizes['product_size'].apply(len)
product_sizes = product_sizes.sort_values(by = 'size_count', ascending=False, ignore_index=True)
display(product_sizes.head(10))
# Out:
# Group by subcategory and brand to get unique product sizes sold
#                   brand        subcategory  \
# 0           Great Value           Shop all
# 1           Great Value      Not_Available
# 2           Great Value           Shop All
# 3                  GOYA           Shop all
# 4                Iberia           Shop all
# 5  Freshness Guaranteed  Cake and cupcakes
# 6             Hershey's      Not_Available
# 7            Stouffer's           Shop all
# 8            Marketside      Not_Available
# 9            Marketside           Shop all
#
#                                         product_size  size_count
# 0  [0, 4, 2, 3, 1, 26, 5, 15, 8, 17, 7, 10, 18, 1...          58
# 1  [16, 48, 0, 17, 25, 14, 128, 101, 51, 29, 54, ...          56
# 2  [16, 0, 33, 28, 25, 41, 7, 32, 26, 35, 24, 29,...          37
# 3  [8, 6, 0, 1, 11, 28, 4, 3, 16, 7, 25, 17, 34, ...          37
# 4  [12, 32, 9, 11, 1, 25, 34, 51, 68, 17, 15, 16,...          36
# 5  [7, 16, 0, 5, 45, 18, 33, 37, 2, 44, 6, 39, 15...          31
# 6  [3, 0, 10, 32, 4, 5, 15, 1, 13, 33, 11, 19, 35...          30
# 7  [10, 0, 12, 9, 32, 19, 11, 8, 57, 36, 33, 34, ...          28
# 8  [10, 16, 11, 12, 24, 15, 6, 17, 0, 7, 4, 18, 8...          27
# 9  [10, 12, 8, 9, 1, 6, 16, 7, 0, 20, 32, 23, 3, ...          26

# %%
f.print_in_red("Top 5 discounted items in categories sold")
f.top_5_bar_plot(discount_df, 'category','discount', 'Category', 'Number of Items Sold With Discount', 'Items Sold With Discount Across Categories', 'top5_categories_with_discount')
# Out:
# Top 5 discounted items in categories sold

# %%
f.print_in_red("Top 5 discounted items in brands sold")
f.top_5_bar_plot(discount_df, 'brand','discount', 'Brand', 'Number of Items Sold With Discount', 'Items Sold With Discount Across Brands','top5_brands_with_discount')
# Out:
# Top 5 discounted items in brands sold

# %%
f.print_in_red("Top 5 discounted products sold")
f.top_5_bar_plot(discount_df, 'product_name','discount', 'Product Name', 'Number of Items Sold With Discount', 'Products Sold With Discount','top5_products_with_discount')
# Out:
# Top 5 discounted products sold

# %%
f.print_in_red("Top 5 discounted items in departments sold")
f.top_5_bar_plot(discount_df, 'department','discount', 'Department', 'Number of Items Sold With Discount', 'Items Sold With Discount Across Departments','top5_departments_with_discount')
# Out:
# Top 5 discounted items in departments sold

# %%
f.print_in_red("Top 5 discounted items in categories sold")
f.top_5_bar_plot(discount_df, 'brand','discount', 'Brand', 'Number of Items Sold With Discount', 'Items Sold With Discount Across Categories','top5_categories_with_discount')
# Out:
# Top 5 discounted items in categories sold

# %%
# Group by brand and count the number of sales, then sort in descending order
f.top_bottom_5_bar_plot(walmart_df,'brand','Brand','Number of Sales','5 Brands by Number of Sales','topAndBottom5_brands')

# %%
# Group by department and count the number of sales, then sort in descending order
f.top_bottom_5_bar_plot(walmart_df,'department','Department','Number of Sales','5 Departments by Number of Sales','topAndBottom5_departments_sales')

# %%
# Group by category and count the number of sales, then sort in descending order
f.top_bottom_5_bar_plot(walmart_df,'category','Category','Number of Sales','5 Categories by Number of Sales','topAndBottom5_categories_sales')

# %%
# Group by subcategory and count the number of sales, then sort in descending order
f.top_bottom_5_bar_plot(walmart_df,'subcategory','Subcategory','Number of Sales','5 Subcategories by Number of Sales','topAndBottom5_subcategories_sales')

# %%
# Group by product_name and count the number of sales, then sort in descending order
sales_by_product = walmart_df.groupby('product_name').size().sort_values(ascending=False)

# Bar plot for visualization
plt.figure(figsize=(14, 10))

# Plotting top products
plt.subplot(1, 2, 1)
plt.bar(sales_by_product.index[:5], sales_by_product.values[:5], color='skyblue')
plt.xlabel('Product Name', fontsize=12)
plt.ylabel('Number of Sales', fontsize=12)
plt.title('Top 5 Products by Number of Sales', fontsize=14)
plt.xticks(rotation=25, ha='right', fontsize=10)
plt.yticks

# Plotting bottom products
plt.subplot(1, 2, 2)
plt.bar(sales_by_product.index[-5:], sales_by_product.values[-5:], color='salmon')
plt.xlabel('Product Name', fontsize=12)
plt.ylabel('Number of Sales', fontsize=12)
plt.title('Top 5 Products by Number of Sales', fontsize=14)
plt.xticks(rotation=25, ha='right', fontsize=10)
plt.yticks

plt.tight_layout()
plt.savefig("../images/topAndBottom5_products_sales.png")
plt.show()

# %%
#Counting the total number of sales by department
department_count = walmart_df['department'].value_counts().reset_index()
#renaming column names from the above department_count table
department_count.columns = ['department', 'count']

plt.figure(figsize=(8, 8))
plt.pie(department_count['count'], labels=department_count['department'], autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Department Sales percentage\n')
plt.savefig("../images/department_sales_percentage.png")
plt.show()

# %%
# Grouping and applying multiple aggregations
aggregated_data = walmart_df.groupby(
    ['brand', 'department', 'category', 'subcategory', 'product_name', 'shipping_location']
).agg({
    'price_current': ['sum', 'mean'],
    'sku': 'count'  # Using SKU count as a proxy for product count
}).reset_index()

# Renaming columns for better readability
aggregated_data.columns = [
    'brand', 'department', 'category', 'subcategory', 'product_name', 'shipping_location',
    'total_sales', 'average_current_price', 'product_count'
]

# Sorting the DataFrame by total sales in descending order
aggregated_data = aggregated_data.sort_values(by='total_sales', ascending=False).reset_index()

# Selecting the top 10 entries
top_10_sellers = aggregated_data.head(10)
top_10_sellers
# Out:
#     index        brand department               category    subcategory  \
# 0  249169      Hi-Chew      Candy    Gummy & chewy candy  Not_Available
# 1  374429        Ninja     Coffee     Coffee Accessories  Coffee Makers
# 2  374427        Ninja     Coffee     Coffee Accessories  Coffee Makers
# 3  374433        Ninja     Coffee     Coffee Accessories  Coffee Makers
# 4  374434        Ninja     Coffee     Coffee Accessories  Coffee Makers
# 5  374432        Ninja     Coffee     Coffee Accessories  Coffee Makers
# 6  374431        Ninja     Coffee     Coffee Accessories  Coffee Makers
# 7  374428        Ninja     Coffee     Coffee Accessories  Coffee Makers
# 8  374430        Ninja     Coffee     Coffee Accessories  Coffee Makers
# 9  201148  Great Value     Frozen  Frozen Meals & Snacks       Shop all
#
#                                         product_name  shipping_location  \
# 0               Hi Chew Original Mix Candy - 12.7 Oz              77449
# 1  Ninja DualBrew Specialty Coffee System, Single...              23223
# 2  Ninja DualBrew Specialty Coffee System, Single...              15601
# 3  Ninja DualBrew Specialty Coffee System, Single...              75052
# 4  Ninja DualBrew Specialty Coffee System, Single...              77449
# 5  Ninja DualBrew Specialty Coffee System, Single...              70072
# 6  Ninja DualBrew Specialty Coffee System, Single...              48180
# 7  Ninja DualBrew Specialty Coffee System, Single...              23111
# 8  Ninja DualBrew Specialty Coffee System, Single...              44035
# 9         Great Value Breaded Chicken Nuggets, 70 oz              33647
#
#    total_sales  average_current_price  product_count
# 0       246.87                 246.87              1
# 1       198.00                 198.00              1
# 2       198.00                 198.00              1
# 3       198.00                 198.00              1
# 4       198.00                 198.00              1
# 5       198.00                 198.00              1
# 6       198.00                 198.00              1
# 7       198.00                 198.00              1
# 8       198.00                 198.00              1
# 9       162.24                  12.48             13

# %%
f.print_in_red("Average price of sold items by Brand and Subcategory")
display(walmart_df.groupby(["brand","subcategory"])["price_current"].mean())
# Out:
# Average price of sold items by Brand and Subcategory
# brand           subcategory
# "Slap Ya Mama"  Shop all          5.500000
# .               Seafood          12.960000
# 0I              Shop all          4.395500
# 1-2-3           Not_Available     6.005714
#                 Shop all          6.616508
#                                    ...
# simply...       Not_Available     3.729597
#                 Smoothies         3.068889
# vacadillos      Shop all          8.980000
# vibi+           Not_Available     1.780000
# vitaminwater    Not_Available     3.329814
# Name: price_current, Length: 7729, dtype: float64

# %%
# Count the number of SKUs by department and brand
sku_count_by_department_brand = walmart_df.groupby(['department', 'brand'])['sku'].count().reset_index(name='sku_count')
print(sku_count_by_department_brand)
# Out:
#      department         brand  sku_count
# 0       Alcohol  1000 Stories          2
# 1       Alcohol      14 Hands         30
# 2       Alcohol          1800         12
# 3       Alcohol     19 CRIMES         73
# 4       Alcohol      21 Seeds          4
# ...         ...           ...        ...
# 7260     Snacks     barkTHINS         20
# 7261     Snacks       belVita         86
# 7262     Snacks         flipz         76
# 7263     Snacks      popchips          9
# 7264     Snacks     simply...         20
#
# [7265 rows x 3 columns]

# %%
asd = walmart_df.groupby('brand')['product_size'].max()
display(asd)
asd = walmart_df.groupby('brand')['product_size'].min()
display(asd)
# Out:
# brand
# "Slap Ya Mama"       16
# .                     2
# 0I                   10
# 1-2-3                33
# 1-2-3 Gluten Free    33
#                      ..
# sea_best              3
# simply...            89
# vacadillos            0
# vibi+                16
# vitaminwater         20
# Name: product_size, Length: 4368, dtype: int32
# brand
# "Slap Ya Mama"        0
# .                     2
# 0I                   10
# 1-2-3                 0
# 1-2-3 Gluten Free    33
#                      ..
# sea_best              3
# simply...             2
# vacadillos            0
# vibi+                16
# vitaminwater         16
# Name: product_size, Length: 4368, dtype: int32

# %%
walmart_df.groupby(['brand', 'department'])['price_retail'].mean()
# Out:
# brand           department
# "Slap Ya Mama"  Pantry             5.500000
# .               Meat & Seafood    12.960000
# 0I              Frozen             4.395500
# 1-2-3           Baking             6.005714
#                 Pantry             6.616508
#                                     ...
# simply...       Dairy & Eggs       3.580000
#                 Snacks             3.680000
# vacadillos      Pantry             8.980000
# vibi+           Beverages          1.780000
# vitaminwater    Beverages          3.329814
# Name: price_retail, Length: 7265, dtype: float64

# %%
subcategory_count = walmart_df.groupby(['subcategory', 'product_size']).size().reset_index(name='total number of items sold')

display(subcategory_count)

sorted_counts = subcategory_count.sort_values(by='total number of items sold', ascending=False)

display(sorted_counts)
# for sc in walmart_df['subcategory'].unique():
    # if sc != 'Not_Available':
        # display(subcategory_count[subcategory_count['subcategory']==sc])
# Out:
#      subcategory  product_size  total number of items sold
# 0        AriZona             0                           1
# 1        AriZona            11                          63
# 2        AriZona            16                           5
# 3        AriZona            20                           3
# 4        AriZona            23                          44
# ...          ...           ...                         ...
# 1955      Yogurt            24                          41
# 1956      Yogurt            32                         716
# 1957      Yogurt            48                          47
# 1958      Yogurt            56                           8
# 1959      Yogurt            64                           4
#
# [1960 rows x 3 columns]
#                    subcategory  product_size  total number of items sold
# 1142             Not_Available             0                       25492
# 1564                  Shop all             0                       18419
# 1158             Not_Available            16                       16341
# 1154             Not_Available            12                       13464
# 1580                  Shop all            16                       12810
# ...                        ...           ...                         ...
# 1877  Tortillas, Pitas & Wraps            75                           1
# 639                       Eggs            30                           1
# 1875  Tortillas, Pitas & Wraps            60                           1
# 1874  Tortillas, Pitas & Wraps            54                           1
# 0                      AriZona             0                           1
#
# [1960 rows x 3 columns]

# %%
# Distribution of products across categories
plt.figure(figsize=(10, 6))
sns.countplot(data=walmart_df, x='category')
plt.title('Distribution of Products across Categories')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# Distribution of products across subcategories
plt.figure(figsize=(10, 6))
sns.countplot(data=walmart_df, x='subcategory')
plt.title('Distribution of Products across Subcategories')
plt.xlabel('Subcategory')
plt.ylabel('Count')
plt.show()

# Distribution of products across brands
plt.figure(figsize=(10, 6))
sns.countplot(data=walmart_df, x='brand')
plt.title('Distribution of Products across Brands')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.show()

# Price distribution across categories
plt.figure(figsize=(10, 6))
sns.boxplot(data=walmart_df, x='category', y='price_retail')
plt.title('Price Distribution across Categories')
plt.xlabel('Category')
plt.ylabel('Price')
plt.show()

# Price distribution across subcategories
plt.figure(figsize=(10, 6))
sns.boxplot(data=walmart_df, x='subcategory', y='price_retail')
plt.title('Price Distribution across Subcategories')
plt.xlabel('Subcategory')
plt.ylabel('Price')
plt.show()

# Price distribution across brands
plt.figure(figsize=(10, 6))
sns.boxplot(data=walmart_df, x='brand', y='price_retail')
plt.title('Price Distribution across Brands')
plt.xlabel('Brand')
plt.ylabel('Price')
plt.show()

# Relationship between product size and price
plt.figure(figsize=(10, 6))
sns.scatterplot(data=walmart_df, x='product_size', y='price_retail')
plt.title('Product Size vs Price')
plt.xlabel('Product Size')
plt.ylabel('Price')
plt.show()

# Assuming we have a list of shipping locations and their respective counts
location_counts = walmart_df['shipping_location'].value_counts()

# Geographical Heatmap (assuming 'shipping_location' corresponds to geographical data)
plt.figure(figsize=(10, 6))
sns.heatmap(location_counts.values.reshape(-1, 1), annot=location_counts.values, fmt='d', cmap='Blues', yticklabels=location_counts.index)
plt.title('Distribution of Products across Shipping Locations')
plt.xlabel('Count')
plt.ylabel('Shipping Location')
plt.show()

# %%
def analyze_distribution(df, column):
    """
    Analyzes the distribution of products based on the given column
    and returns a bar plot.
    """
    plt.figure(figsize=(10, 6))
    sns.countplot(data=walmart_df, x=column)
    plt.title(f'Distribution of Products across {column.capitalize()}')
    plt.xlabel(column.capitalize())
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()

analyze_distribution(walmart_df, 'category')  
analyze_distribution(walmart_df, 'subcategory')  
analyze_distribution(walmart_df, 'brand')
